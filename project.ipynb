# %% [markdown]
# # Fundamentals of Data Analysis Project
#
# Phelim Barry
#
# ***

# %% [markdown]
# # Summary
#
# The purpose of this notebook is to investigate the variables and data points within the iris flower data set. In this we discuss the classification of each variable within the data set. We will select, demonstrate and explain the most appropriate statistics to describe each variable. We will also select, demonstrate and explain the most appropriate plots for each variable.

# %% [markdown]
# # Table of Contents
#
# 1. [Introduction](#Introduction)
# 2. [Variables Classification](#Classification)
# 3. [Summary Statistics](#Statistics)
# 4. [Plots](#Plots)
# 5. [Summary](#Summary)
# 6. [References](#References)

# %% [markdown]
# # Introduction
#
# The iris data set consists of data published by R. A. Fisher in 1936. It is made up of 150 samples (50 each) of three different types of iris flower - Iris Setosa, Iris Virginica and Iris Versicolor. Each flower was measured for Sepal Length, Sepal Width, Petal Length and Petal Width.
# Although initially used by Fisher to apply his linear discriminant analysis, the data set is widely used today as a beginners learning tool in the areas of machine learning and data analysis $^1$.
#
# The dataset was downloaded from the UC Irvine Machine Learning Repository $^2$ on 29th October 2023.

# %%
# Import required modules

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the CSV file and add column names
# Information on how to add column names during the import taken from https://stackoverflow.com/questions/31645466/give-column-name-when-read-csv-file-pandas
col_names =  ["Sepal_Length", "Sepal_Width", "Petal_Length", "Petal_Width", "Class"]
iris_csv = pd.read_csv('data/iris.data', sep= ",", names=col_names, header=None)

# %%
# Print the contents of the dataframe

iris_csv
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Print summary stats of the dataframe

iris_csv.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Classification
#
# In this section we discuss the classification of each variable within the dataset according to common variable types and scales of measurement within mathematics, statistics and Python.
#
# Variables are typically categorised as being either numeric or categorical. Categorical variables are variables that can be grouped together to describe them. Numeric variables are used to represent numbers and can be described as being either discrete or continuous.
#
# Scales of measurement refer to how variables are defined and categorised based on their characteristics and are important factors when analysing data. At the top level we have two types - qualitative and quantitative. Qualitative generally refers to data that is non numeric and is can be used to define groups or categories of data.
#
# Qualitative variables can be broken down into two groups - nominal, which refer to variables that can describe groups or categories and ordinal which refers to variables that have a defined order. Quantitative variables on the other hand are numeric and represent amounts.
# Quantitative variables can be broken down into two groups also - ratios which can be used to represent ratios and interval which are the opposite to ratio and do not have a true 0.
#
# https://sixsigmastats.com/learn-data-types/
# Maybe get a graphic for this...
#
#
# https://365datascience.com/tutorials/statistics-tutorials/levels-measurement/
# https://www.britannica.com/science/distribution-function
#
# The iris data set contains five different variables as follows:
#
# class
# sepal_length
# sepal_width
# petal_length
# petal_width

# %%
iris_csv.dtypes
# Out:
# Sepal_Length    float64
# Sepal_Width     float64
# Petal_Length    float64
# Petal_Width     float64
# Class            object
# dtype: object

# %% [markdown]
# ### Class
# Using the ```drop_dupicates``` method we can visualise the data in the ```class``` variable

# %%
iris_csv.drop_duplicates(subset ="Class",)
#unique
#iris_csv.Class.describe()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width            Class
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 50            7.0          3.2           4.7          1.4  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica

# %% [markdown]
# We can also use the ```.describe()``` function specifying the column name to get summary data.

# %%
iris_csv.Class.describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: Class, dtype: object

# %% [markdown]
# We can see that it is a categorical variable with three possible values - iris-setosa, iris-versicolor and iris-virginica. This is a nominal variable as it is being used to group or categorise the data by the class of penguin.
# If we were to define class in Python as a variable in its own right then we would use the ```str``` type as it contains alpha characters but by defaut Python defines it as an ```object``` data type.

# %% [markdown]
# ### Sepal_Length
#
# We saw earlier that Sepal_Length has been assigned a type of ```float64``` indicating that it is a numeric value with decimal places. This variable is being used to store the measured length of the sepals for each of the iris flowers.
# To view the data in the Sepal_Length variable we can use ```.describe()``` and can see that it contains 150 values ranging from 4.3 to 7.9.

# %%
iris_csv.Sepal_Length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: Sepal_Length, dtype: float64

# %% [markdown]
# This is a quantitative variable as it is being used to store numbers and is a ratio type variable as there is a true 0 and the differences between the values is meaningful - i.e. a Sepal_Length of 8 would be twice as long as a Sepal_Length of 4.
#
# Using ```float32``` may be overkill for this variable based on the data it is being used to store and using a ```float32``` may be sufficient and could increase performance but may result in loss of accuracy depending on the calculations being performed on the data.

# %% [markdown]
# ### Sepal_Width
#
# We saw earlier that Sepal_Wength has been assigned a type of ```float64``` indicating that it is a numeric value with decimal places. This variable is being used to store the measured width of the sepals for each of the iris flowers.
# To view the data in the Sepal_Wength variable we can use ```.describe()``` and can see that it contains 150 values ranging from 2.0 to 4.4.

# %%
iris_csv.Sepal_Width.describe()
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: Sepal_Width, dtype: float64

# %% [markdown]
# Similar to Sepal_Length, this is also a quantitative variable as it is being used to store numbers and is a ratio type variable as there is a true 0 and the differences between the values is meaningfull - i.e. a Sepal_Width of 4 would be twice as long as a Sepal_Width of 2.
#
# Using ```float32``` may again be overkill for this variable based on the data it is being used to store and using a ```float32``` may be sufficient.

# %% [markdown]
# ### Petal_Length
#
# From earlier we saw that Petal_Length has been assigned a type of ```float64``` indicating that it is a numeric value with decimal places. This variable is being used to store the measured length of the petals for each of the iris flowers.
# To view the data in the Petal_Length variable we can use ```.describe()``` and can see that it contains 150 values ranging from 1.0 to 6.9.

# %%
iris_csv.Petal_Length.describe()
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: Petal_Length, dtype: float64

# %% [markdown]
# Similar to Sepal_Length and Sepal_Width, this is also a quantitative variable as it is being used to store numbers and is a ratio type variable as there is again a true 0 and the differences between the values is meaningfull - i.e. a Petal_Length of 6 would be twice as long as a Petal_Length of 3.
#
# Using ```float32``` may again be overkill for this variable based on the data it is being used to store and using a ```float32``` may be sufficient.

# %% [markdown]
# ### Petal_Width
#
# From earlier we saw that Petal_Width has been assigned a type of ```float64``` indicating that it is a numeric value with decimal places. This variable is being used to store the measured width of the petals for each of the iris flowers.
# To view the data in the Petal_Width variable we can use ```.describe()``` and can see that it contains 150 values ranging from 0.1 to 2.5.

# %%
iris_csv.Petal_Width.describe()
# Out:
# count    150.000000
# mean       1.198667
# std        0.763161
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: Petal_Width, dtype: float64

# %% [markdown]
# Similar to Petal_Length, this is also a quantitative variable as it is being used to store numbers and is a ratio type variable as there is again a true 0 and the differences between the values is meaningfull - i.e. a Petal_Width of 4 would be twice as long as a Petal_Width of 2.
#
# As with the other variables, using ```float32``` may be overkill for this variable based on the data it is being used to store and using a ```float32``` may be sufficient.

# %% [markdown]
# # Statistics
#
# In this section we will select, demonstrate and explain the most appropriate summary statistics to describe each variable.

# %% [markdown]
# ### Class
# Given that the class variable is categorical/nominal then the most appropriate or useful statistic is the count of each value. We know there are only three possible values and using the ```value_counts``` function we can see a summary of the data.

# %%
# Calculate and display the count of values in the Class variable

class_count = iris_csv.value_counts("Class")
class_count
# Out:
# Class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# We can see that there is an equal distribution of the different classes, with each having 50 values.

# %% [markdown]
# ### Sepal_Length
#
# Sepal_length is a numeric value and we can use the ```.describe()``` function specifying the column name to get summary statistics.

# %%
iris_csv.Sepal_Length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: Sepal_Length, dtype: float64

# %% [markdown]
# From this we can see the count, min, max, median, standard deviation and the 25th, 50th and 75% percentile. We can also see the variable type is a float (float64).

# %% [markdown]
# ### Sepal_Width
#
# Sepal_width is a numeric value and we can use the ```.describe()``` function specifying the column name to get summary statistics.

# %%
iris_csv.Sepal_Width.describe()
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: Sepal_Width, dtype: float64

# %% [markdown]
# From this we again see the count, min, max, median, standard deviation and the 25th, 50th and 75% percentile. We can also see the variable type is a float (float64).

# %% [markdown]
# ### Petal_Length
#
# Petal_length is a numeric value and we again use the ```.describe()``` function specifying the column name to get summary statistics.

# %%
iris_csv.Petal_Length.describe()
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: Petal_Length, dtype: float64

# %% [markdown]
# From this we again see the count, min, max, median, standard deviation and the 25th, 50th and 75% percentile. We can also see the variable type is a float (float64).

# %% [markdown]
# ### Petal_Width
#
# Petal_Width is a numeric value and we again use the ```.describe()``` function specifying the column name to get summary statistics.

# %%
iris_csv.Petal_Width.describe()
# Out:
# count    150.000000
# mean       1.198667
# std        0.763161
# min        0.100000
# 25%        0.300000
# 50%        1.300000
# 75%        1.800000
# max        2.500000
# Name: Petal_Width, dtype: float64

# %% [markdown]
# From this we again see the count, min, max, median, standard deviation and the 25th, 50th and 75% percentile. We can also see the variable type is a float (float64).

# %% [markdown]
# # Plots
#
# In this section we will select, demonstrate and explain the most appropriate plot(s) for each variable.
#
# As a reminder, the iris data set contains the following five variables:
#
# class
# sepal_length
# sepal_width
# petal_length
# petal_width

# %% [markdown]
# ### Class
# As seen above, the Class variable is categorical with only three different values. We also know that each value has a count of 50. To plot this data, a bar chart or pie chart would be most appropriate.

# %%
# Create a list for Class and plot a bar chart

class_l = []
for x in iris_csv['Class']:
    class_l.append(x)

temp_class=np.unique(class_l)

freq_list2 = []
for x in temp_class:
    freq_list2.append(class_l.count(x))

plt.title('Distribution of values for "Class" variable')

plt.pie(freq_list2, labels = temp_class, autopct='%1.1f%%');

# Use the below if we want to show a bar chart instead
#plt.xlabel("Flower Name")
#plt.ylabel("Count")
#plt.bar(temp_class, freq_list2);

# %% [markdown]
# ### Sepal_Length
# The sepal_length is a numeric variable with 150 values and as seen above they range in size from 4.3 to 7.9mm. Using ```nunique()``` we can see that there are actually 35 unique values in total. Given the spread and quantity of data the best plot to use to visualise it is a histogram.
#
# The height of each bar (called bins) shows how many values fall within each range.

# %%
iris_csv['Sepal_Length'].nunique()
# Out:
# 35

# %%
# Create a list just for Sepal Length and generate a histogram
sepal_l = []
for iris in iris_csv['Sepal_Length']:
    sepal_l.append(iris)
#Sort the list before creating the histogram
sepal_l.sort()
#Add title and labels
plt.title("Sepal Length")
plt.xlabel("Length (cm)")
plt.ylabel("Frequency")
plt.hist(sepal_l);

# %% [markdown]
# However, as we can see from the output above the histogram is not normally distributed and is showing multiple nodes. This is because we are plotting all three flower types as one. To more better visualise the data we can split the plot by flower type as follows:

# %%
# Split out each flower type into seperate variables for use in later plots
iris_setosa=iris_csv.loc[iris_csv["Class"]=="Iris-setosa"]
iris_virginica=iris_csv.loc[iris_csv["Class"]=="Iris-virginica"]
iris_versicolor=iris_csv.loc[iris_csv["Class"]=="Iris-versicolor"]
# Sort the data
iris_setosa.sort_values("Sepal_Length");
iris_virginica.sort_values("Sepal_Length");
iris_versicolor.sort_values("Sepal_Length");

# %%
# Plot a histogram for Sepal_Length with 3 data elements

#Add title and labels
plt.title("Sepal Length Comparison")
plt.xlabel("Length (cm)")
plt.ylabel("Frequency")
#create the plots
plt.hist(iris_setosa["Sepal_Length"],label='iris_setosa')
plt.hist(iris_virginica["Sepal_Length"],label='iris_virginica')
plt.hist(iris_versicolor["Sepal_Length"],label='iris_versicolor')
plt.legend();

# %% [markdown]
# We can now see the flower types individually and can get a better view of the data.

# %% [markdown]
# ### Sepal Width
# The sepal_width is a numeric variable with 150 values and as seen above they range in size from 2.0 to 4.4mm. Using ```nunique()``` again, we can see that there are actually 23 unique values in total. Given the spread and quantity of data the best plot to use to visualise it is a histogram.
#
# As with the sepal_length we will bypass plotting one single plot with all the data combined and just plot the three species individually on one plot to get a better view of the data.

# %%
iris_csv['Sepal_Width'].nunique()
# Out:
# 23

# %%
# Plot a histogram for Sepal_Width with 3 data elements

#Add title and labels
plt.title("Sepal Width Comparison")
plt.xlabel("Length (cm)")
plt.ylabel("Frequency")
# Create the plots
plt.hist(iris_setosa["Sepal_Width"],label='iris_setosa')
plt.hist(iris_virginica["Sepal_Width"],label='iris_virginica')
plt.hist(iris_versicolor["Sepal_Width"],label='iris_versicolor')
plt.legend();
#plt.savefig("Sepal_Length_Comparison_Histogram.png")

# %% [markdown]
# We can now see the flower types individually.

# %% [markdown]
# ### Petal_Length
# The petal_length is a numeric variable with 150 values and as seen above they range in size from 1.0 to 6.9mm. Using ```nunique()``` again, we can see that there are actually 43 unique values in total. Given the spread and quantity of data the best plot to use to visualise it is a histogram.
#
# As with the previous plots we will bypass plotting one single plot with all the data combined and just plot the three species individually on one plot to get a better view of the data.

# %%
iris_csv['Petal_Length'].nunique()
# Out:
# 43

# %%
# Plot a histogram for Petal_Length with 3 data elements

# Add title and labels
plt.title("Petal Length Comparison")
plt.xlabel("Length (cm)")
plt.ylabel("Frequency")
# Create the plots
plt.hist(iris_setosa["Petal_Length"],label='iris_setosa')
plt.hist(iris_virginica["Petal_Length"],label='iris_virginica')
plt.hist(iris_versicolor["Petal_Length"],label='iris_versicolor')
plt.legend();

# %% [markdown]
# We can now see the flower types individually and can clearly see how the data looks.

# %% [markdown]
# ### Petal_Width
# The petal_width is a numeric variable with 150 values and as seen above they range in size from 0.1 to 2.5mm. Using ```nunique()``` again, we can see that there are actually 22 unique values in total. Given the spread and quantity of data the best plot to use to visualise it is a histogram.
#
# As with the previous plots we will bypass plotting one single plot with all the data combined and just plot the three species individually on one plot to get a better view of the data.

# %%
iris_csv['Petal_Width'].nunique()
# Out:
# 22

# %%
# Plot a histogram for Petal_Width with 3 data elements

# Add title and labels
plt.title("Petal Width Comparison")
plt.xlabel("Length (cm)")
plt.ylabel("Frequency")
# Create the plots
plt.hist(iris_setosa["Petal_Width"],label='iris_setosa')
plt.hist(iris_virginica["Petal_Width"],label='iris_virginica')
plt.hist(iris_versicolor["Petal_Width"],label='iris_versicolor')
plt.legend();

# %% [markdown]
# We can now see the flower types individually and can clearly see how the data looks.

# %% [markdown]
# We can dig deeper into the plotting capabilities using seaborn and create scatterplots to compare two sets of data. For example we can create a scatterplot to compare the relationship between Petal Length and Petal width

# %%
# Create Scatterplot using seaborn with colours for each flower type
# Petal Length and Petal Width comparison

# Define the data for x and y axis
x_axis = iris_csv['Petal_Length']
y_axis = iris_csv['Petal_Width']

# Add a title and labels
plt.title("Petal length | Petal Width")
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')

sns.scatterplot(x=x_axis, y=y_axis, hue=iris_csv.Class, s=90)

# Plot Regression Line
# Code taken from : https://www.adamsmith.haus/python/answers/how-to-plot-a-linear-regression-line-on-a-scatter-plot-in-python
m, b = np.polyfit(x_axis, y_axis, 1)
plt.plot(x_axis, m*x_axis + b);

# %% [markdown]
# From the scatterplot we can see for example, that there is a strong linear relationship between Petal Length and Petal Width, as petal_length increases so does petal_width.

# %% [markdown]
# Similarily, we can create a scatterplot to compare the relationship between Sepal Length and Sepal width

# %%
# Sepal Length and Sepal Width comparison

# Define the data for x and y axis
x_axis = iris_csv['Sepal_Length']
y_axis = iris_csv['Sepal_Width']

# Add a title and labels
plt.title("Sepal length | Sepal width")
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')

sns.scatterplot(x=x_axis, y=y_axis, hue=iris_csv.Class, s=90)

# Plot Regression Line
# Code taken from : https://www.adamsmith.haus/python/answers/how-to-plot-a-linear-regression-line-on-a-scatter-plot-in-python
m, b = np.polyfit(x_axis, y_axis, 1)
plt.plot(x_axis, m*x_axis + b);

# %% [markdown]
# From the scatter plot we can see this time that there is a weak negative relationship between the two variables.

# %% [markdown]
# To further visualise the relationships plotted above (and for the rest of the data set) we could use a Correllation Heatmap to plot the strength of correllation between each variable as follows:

# %%
# Plotting a Heatmap using seaborn to show correlations
iris_csv_sns = iris_csv.drop("Class", axis=1) # Removing class variable
sns.heatmap(iris_csv_sns.corr(method='pearson'), cmap="YlGnBu", annot=True); 
plt.title("Heatmap - Pearsons Correllation");

# %% [markdown]
# This plot shows us where the association between two variables is weak or strong and the direction of the association. For example, Petal_Length and Petal_Width have a value of 0.96 which indicates a very strong positive relationship between the two variables.

# %% [markdown]
# Finally, we can use seaborn to produce a pairplot which shows, at a glance a mix of individual plots and combined plots for each variable.

# %%
# Pair Plot
# import seaborn as sns
sns.pairplot(iris_csv, hue='Class');

# %% [markdown]
# # Summary

# %% [markdown]
# # References
#
# $^1$ https://en.wikipedia.org/wiki/Iris_flower_data_set
# $^2$ https://archive.ics.uci.edu/dataset/53/iris
#
# regression line for scatter plots
# https://www.adamsmith.haus/python/answers/how-to-plot-a-linear-regression-line-on-a-scatter-plot-in-python

# %% [markdown]
# ***
#
# ## End
